# %%
# Using VIX index as a predictor of Russell 2000 prices to test using percentage change of expectation of volatility index against the percent change of the price of a stock index.

# %%
## Data Preparation
# 1. Rolling 10 day window (ten trading days)
# 2. 70% training data 30% testing data
# 3. Use MinMaxScaler to X and y values

# %%
# Imports

import yfinance as yf
import numpy as np
import pandas as pd
import hvplot.pandas

# %%
# Setting random seed for testing - will comment out for final product

#from numpy.random import seed
#seed(1)
#from tensorflow import random
#random.set_seed(2)

# %%
# Load price data for VIX using yfinance

index_df = yf.download("^VIX", start='2019-01-01', end='2021-05-31')
index_df = index_df.drop(columns = ['Open', 'High', 'Low', 'Adj Close', 'Volume']).rename(columns = {'Close':'^VIX'})
index_df = index_df['^VIX'].pct_change()
index_df = index_df.dropna()
index_df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2019-01-03    0.096038
# 2019-01-04   -0.159921
# 2019-01-07    0.000935
# 2019-01-08   -0.043458
# 2019-01-09   -0.023937
# Name: ^VIX, dtype: float64

# %%
# Load price data for RUT using yfinance
stock_df = yf.download("^RUT", start='2019-01-01', end='2021-05-31')
stock_df = stock_df.drop(columns = ['Open', 'High', 'Low', 'Adj Close', 'Volume']).rename(columns = {'Close':'^RUT'})
stock_df = stock_df['^RUT'].pct_change()
stock_df = stock_df.dropna()
stock_df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2019-01-03   -0.018497
# 2019-01-04    0.037510
# 2019-01-07    0.017831
# 2019-01-08    0.015071
# 2019-01-09    0.008594
# Name: ^RUT, dtype: float64

# %%
# Concatenate into single df

df = pd.concat([index_df, stock_df], axis="columns", join="inner")
df
# Out:
#                 ^VIX      ^RUT
# Date
# 2019-01-03  0.096038 -0.018497
# 2019-01-04 -0.159921  0.037510
# 2019-01-07  0.000935  0.017831
# 2019-01-08 -0.043458  0.015071
# 2019-01-09 -0.023937  0.008594
# 2019-01-10 -0.024024  0.004601
# 2019-01-11 -0.067179  0.001349
# 2019-01-14  0.048378 -0.010066
# 2019-01-15 -0.024646  0.008661
# 2019-01-16  0.023656  0.006560
# 2019-01-17 -0.051471  0.008627
# 2019-01-18 -0.014396  0.010394
# 2019-01-22  0.168539 -0.016897
# 2019-01-23 -0.061538 -0.002189
# 2019-01-24 -0.032275  0.006980
# 2019-01-25 -0.077819  0.012592
# 2019-01-28  0.083238 -0.006278
# 2019-01-29  0.013778 -0.001418
# 2019-01-30 -0.076843  0.010527
# 2019-01-31 -0.061721  0.008393
# 2019-02-01 -0.025951  0.001754
# 2019-02-04 -0.025403  0.010313
# 2019-02-05 -0.010172  0.001773
# 2019-02-06 -0.012203 -0.001454
# 2019-02-07  0.064369 -0.008162
# 2019-02-08 -0.039707  0.000505
# 2019-02-11  0.015903  0.008358
# 2019-02-12 -0.033813  0.012673
# 2019-02-13  0.014258  0.003062
# 2019-02-14  0.036422  0.001406
# ...              ...       ...
# 2021-04-19  0.064000 -0.013555
# 2021-04-20  0.080393 -0.019619
# 2021-04-21 -0.063169  0.023499
# 2021-04-22  0.069143 -0.003134
# 2021-04-23 -0.073757  0.017580
# 2021-04-26  0.017888  0.011510
# 2021-04-27 -0.004535  0.001419
# 2021-04-28 -0.015945  0.001256
# 2021-04-29  0.019097 -0.003776
# 2021-04-30  0.056786 -0.012638
# 2021-05-03 -0.016120  0.004853
# 2021-05-04  0.063900 -0.012804
# 2021-05-05 -0.016940 -0.003078
# 2021-05-06 -0.039687  0.000022
# 2021-05-07 -0.092441  0.013478
# 2021-05-10  0.177951 -0.025942
# 2021-05-11  0.110885 -0.002581
# 2021-05-12  0.263278 -0.032556
# 2021-05-13 -0.161653  0.016772
# 2021-05-14 -0.186770  0.024726
# 2021-05-17  0.048379  0.001119
# 2021-05-18  0.082150 -0.007292
# 2021-05-19  0.039363 -0.007798
# 2021-05-20 -0.068079  0.006437
# 2021-05-21 -0.025157  0.003402
# 2021-05-24 -0.086849  0.005449
# 2021-05-25  0.023913 -0.009693
# 2021-05-26 -0.078556  0.019730
# 2021-05-27 -0.035714  0.010581
# 2021-05-28  0.001195 -0.001804
#
# [606 rows x 2 columns]

# %%
# Below function takes column number for the features (X) and target (y)
# It accumulates the data with a rolling window of X(t-n) to predict Xt
# Finally, it returns a numpy array of X and y

def window_data(df, window, feature_col_number, target_col_number):
    X = []
    y = []
    print(len(df) - window - 1)
    for i in range(len(df) - window - 1):
        features = df.iloc[i:(i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Predict Closing Prices using a 10 day window of previous closing prices

window_size = 10

# Column index 0 is the 'index' column
# Column index 1 is the 'stock' column
feature_column = 0
target_column = 1
X, y = window_data(df, window_size, feature_column, target_column)
# Out:
# 595

# %%
# 70% of data will be for training and 30% for testing

from sklearn.model_selection import train_test_split
split = int(0.7 * len(X))
X_train = X[: split]
X_test = X[split:]
y_train = y[: split]
y_test = y[split:]

# %%
# Scaling data between 0 and 1

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
scaler.fit(y)
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %%
# Reshape the features for the model

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
## Building/training LSTM RNN

# %%
# Imports from tensorflow

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# LSTM Model
# How many layers are we doing? Check before doing return sequences. Set to True if adding more LSTM layers but not for final layer
# Input shape: number of time steps and number of indicators
# Dropouts to prevent overfitting
# Define the LSTM RNN model
# Using 10 units per layer to match the window size of 10
# Randomly dropping 20% of neurons per epoch

model = Sequential()

number_units = 10
dropout_fraction = 0.2

# Layer 1

model.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))
# Layer 2

model.add(LSTM(units=number_units, return_sequences=True))
model.add(Dropout(dropout_fraction))
# Layer 3

model.add(LSTM(units=number_units))
model.add(Dropout(dropout_fraction))
# Output layer

model.add(Dense(1))

# %%
# Compile the model
# What is Adam?

model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Summarize the model

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 10, 10)            480
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 10, 10)            0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 10, 10)            840
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 10, 10)            0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 10)                840
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 2,171
# Trainable params: 2,171
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model

model.fit(X_train, y_train, epochs=50, shuffle=False, batch_size=1, verbose=1)
# Out:
# Epoch 1/50
# 416/416 [==============================] - 15s 13ms/step - loss: 0.0878
# Epoch 2/50
# 416/416 [==============================] - 6s 13ms/step - loss: 0.0132
# Epoch 3/50
# 416/416 [==============================] - 5s 13ms/step - loss: 0.0111
# Epoch 4/50
# 416/416 [==============================] - 7s 16ms/step - loss: 0.0102
# Epoch 5/50
# 416/416 [==============================] - 7s 17ms/step - loss: 0.0089
# Epoch 6/50
# 416/416 [==============================] - 7s 18ms/step - loss: 0.0084
# Epoch 7/50
# 416/416 [==============================] - 7s 17ms/step - loss: 0.0070
# Epoch 8/50
# 416/416 [==============================] - 6s 15ms/step - loss: 0.0057
# Epoch 9/50
# 416/416 [==============================] - 7s 16ms/step - loss: 0.0059
# Epoch 10/50
# 416/416 [==============================] - 7s 17ms/step - loss: 0.0052
# Epoch 11/50
# 416/416 [==============================] - 7s 16ms/step - loss: 0.0055
# Epoch 12/50
# 416/416 [==============================] - 7s 17ms/step - loss: 0.0045
# Epoch 13/50
# 416/416 [==============================] - 8s 20ms/step - loss: 0.0045
# Epoch 14/50
# 416/416 [==============================] - 7s 18ms/step - loss: 0.0044
# Epoch 15/50
# 416/416 [==============================] - 8s 20ms/step - loss: 0.0045
# Epoch 16/50
# 416/416 [==============================] - 8s 18ms/step - loss: 0.0043
# Epoch 17/50
# 416/416 [==============================] - 8s 19ms/step - loss: 0.0041: 1s -
# Epoch 18/50
# 416/416 [==============================] - 6s 14ms/step - loss: 0.0041
# Epoch 19/50
# 416/416 [==============================] - 6s 15ms/step - loss: 0.0040
# Epoch 20/50
# 416/416 [==============================] - 6s 15ms/step - loss: 0.0042
# Epoch 21/50
# 416/416 [==============================] - 7s 16ms/step - loss: 0.0040
# Epoch 22/50
# 416/416 [==============================] - 8s 20ms/step - loss: 0.0041
# Epoch 23/50
# 416/416 [==============================] - 8s 19ms/step - loss: 0.0039: 0s - loss: 0 - ETA: 0
# Epoch 24/50
# 416/416 [==============================] - 8s 19ms/step - loss: 0.0039
# Epoch 25/50
# 416/416 [==============================] - 8s 19ms/step - loss: 0.0040
# Epoch 26/50
# 416/416 [==============================] - 9s 22ms/step - loss: 0.0038: 2s - ETA: 1 -
# Epoch 27/50
# 416/416 [==============================] - 11s 26ms/step - loss: 0.0039 0s - loss: 0.003
# Epoch 28/50
# 416/416 [==============================] - 7s 17ms/step - loss: 0.0038A:
# Epoch 29/50
# 416/416 [==============================] - 8s 19ms/step - loss: 0.0039
# Epoch 30/50
# 416/416 [==============================] - 8s 18ms/step - loss: 0.0038
# Epoch 31/50
# 416/416 [==============================] - 7s 16ms/step - loss: 0.0038
# Epoch 32/50
# 416/416 [==============================] - 8s 20ms/step - loss: 0.0038
# Epoch 33/50
# 416/416 [==============================] - 7s 18ms/step - loss: 0.0038
# Epoch 34/50
# 416/416 [==============================] - 9s 21ms/step - loss: 0.0038
# Epoch 35/50
# 416/416 [==============================] - 10s 24ms/step - loss: 0.0038
# Epoch 36/50
# 416/416 [==============================] - 8s 20ms/step - loss: 0.0037
# Epoch 37/50
# 416/416 [==============================] - 9s 21ms/step - loss: 0.0038
# Epoch 38/50
# 416/416 [==============================] - 8s 19ms/step - loss: 0.0037: 3s  - ETA: 2s - loss: 0. - ETA: - ETA:
# Epoch 39/50
# 416/416 [==============================] - 8s 18ms/step - loss: 0.0038
# Epoch 40/50
# 416/416 [==============================] - 8s 19ms/step - loss: 0.0037
# Epoch 41/50
# 416/416 [==============================] - 9s 22ms/step - loss: 0.0037
# Epoch 42/50
# 416/416 [==============================] - 10s 23ms/step - loss: 0.0037
# Epoch 43/50
# 416/416 [==============================] - 10s 23ms/step - loss: 0.0037
# Epoch 44/50
# 416/416 [==============================] - 8s 20ms/step - loss: 0.0037
# Epoch 45/50
# 416/416 [==============================] - 8s 20ms/step - loss: 0.0038
# Epoch 46/50
# 416/416 [==============================] - 9s 22ms/step - loss: 0.0037
# Epoch 47/50
# 416/416 [==============================] - 9s 21ms/step - loss: 0.0037
# Epoch 48/50
# 416/416 [==============================] - 8s 19ms/step - loss: 0.0038
# Epoch 49/50
# 416/416 [==============================] - 8s 19ms/step - loss: 0.0037
# Epoch 50/50
# 416/416 [==============================] - 8s 20ms/step - loss: 0.0037

# %%
## Model Performance

# %%
# Evaluate the model

model.evaluate(X_test, y_test)
# Out:
# 6/6 [==============================] - 3s 7ms/step - loss: 0.0041
# 0.004115000832825899

# %%
# Predictions

predicted = model.predict(X_test)

# %%
# Recover the unscaled prices

predicted_prices = scaler.inverse_transform(predicted)
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Create df of predicted and real prices

stocks = pd.DataFrame({
    "Real": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
}, index = df.index[-len(real_prices): ]) 
stocks.head()
# Out:
#                 Real  Predicted
# Date
# 2020-09-14 -0.006951   0.001552
# 2020-09-15  0.026515   0.001647
# 2020-09-16  0.000768   0.001727
# 2020-09-17  0.009219   0.001774
# 2020-09-18 -0.006268   0.001773

# %%
# Real vs predicted line plot to check fit

stocks.plot(title="Real vs Predicted Price Changes using VIX as a predictor of RUT")

# %%
#Importing for correlation

index_df = yf.download("^VIX", start='2019-01-01', end='2021-05-31')
index_df = index_df.drop(columns = ['Open', 'High', 'Low', 'Adj Close', 'Volume']).rename(columns = {'Close':'VIX^'})
index_df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  VIX^
# Date
# 2019-01-02  23.219999
# 2019-01-03  25.450001
# 2019-01-04  21.379999
# 2019-01-07  21.400000
# 2019-01-08  20.469999

# %%
stock_df = yf.download("^RUT", start='2019-01-01', end='2021-05-31')
stock_df = stock_df.drop(columns = ['Open', 'High', 'Low', 'Adj Close', 'Volume']).rename(columns = {'Close':'^RUT'})
stock_df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    ^RUT
# Date
# 2019-01-02  1355.910034
# 2019-01-03  1330.829956
# 2019-01-04  1380.750000
# 2019-01-07  1405.369995
# 2019-01-08  1426.550049

# %%
df = pd.concat([index_df, stock_df], axis="columns", join="inner")
df
# Out:
#                  VIX^         ^RUT
# Date
# 2019-01-02  23.219999  1355.910034
# 2019-01-03  25.450001  1330.829956
# 2019-01-04  21.379999  1380.750000
# 2019-01-07  21.400000  1405.369995
# 2019-01-08  20.469999  1426.550049
# 2019-01-09  19.980000  1438.810059
# 2019-01-10  19.500000  1445.430054
# 2019-01-11  18.190001  1447.380005
# 2019-01-14  19.070000  1432.810059
# 2019-01-15  18.600000  1445.219971
# 2019-01-16  19.040001  1454.699951
# 2019-01-17  18.059999  1467.250000
# 2019-01-18  17.799999  1482.500000
# 2019-01-22  20.799999  1457.449951
# 2019-01-23  19.520000  1454.260010
# 2019-01-24  18.889999  1464.410034
# 2019-01-25  17.420000  1482.849976
# 2019-01-28  18.870001  1473.540039
# 2019-01-29  19.129999  1471.449951
# 2019-01-30  17.660000  1486.939941
# 2019-01-31  16.570000  1499.420044
# 2019-02-01  16.139999  1502.050049
# 2019-02-04  15.730000  1517.540039
# 2019-02-05  15.570000  1520.229980
# 2019-02-06  15.380000  1518.020020
# 2019-02-07  16.370001  1505.630005
# 2019-02-08  15.720000  1506.390015
# 2019-02-11  15.970000  1518.979980
# 2019-02-12  15.430000  1538.229980
# 2019-02-13  15.650000  1542.939941
# ...               ...          ...
# 2021-04-19  17.290001  2232.000000
# 2021-04-20  18.680000  2188.209961
# 2021-04-21  17.500000  2239.629883
# 2021-04-22  18.709999  2232.610107
# 2021-04-23  17.330000  2271.860107
# 2021-04-26  17.639999  2298.010010
# 2021-04-27  17.559999  2301.270020
# 2021-04-28  17.280001  2304.159912
# 2021-04-29  17.610001  2295.459961
# 2021-04-30  18.610001  2266.449951
# 2021-05-03  18.309999  2277.449951
# 2021-05-04  19.480000  2248.290039
# 2021-05-05  19.150000  2241.370117
# 2021-05-06  18.389999  2241.419922
# 2021-05-07  16.690001  2271.629883
# 2021-05-10  19.660000  2212.699951
# 2021-05-11  21.840000  2206.989990
# 2021-05-12  27.590000  2135.139893
# 2021-05-13  23.129999  2170.949951
# 2021-05-14  18.809999  2224.629883
# 2021-05-17  19.719999  2227.120117
# 2021-05-18  21.340000  2210.879883
# 2021-05-19  22.180000  2193.639893
# 2021-05-20  20.670000  2207.760010
# 2021-05-21  20.150000  2215.270020
# 2021-05-24  18.400000  2227.340088
# 2021-05-25  18.840000  2205.750000
# 2021-05-26  17.360001  2249.270020
# 2021-05-27  16.740000  2273.070068
# 2021-05-28  16.760000  2268.969971
#
# [607 rows x 2 columns]

# %%
# Correlation graphs

correlation = df.corr()
correlation
# Out:
#           VIX^      ^RUT
# VIX^  1.000000 -0.354674
# ^RUT -0.354674  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation, vmin=-1, vmax=1)

# %%
# Additional visuals

df.plot(title="VIX vs RUT prices from Jan 2019 to May 2021")
